# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns

# %%
df = pd.read_csv('/content/Data.csv')

# %%
df
# Out:
#       CylindricalConcreteCompressiveStrength  YieldStrength      H  \
# 0                                       33.2          437.0  155.0
# 1                                       35.6          437.0  155.0
# 2                                       26.0          437.0  155.0
# 3                                       26.0          437.0  155.0
# 4                                       26.0          437.0  155.0
# ..                                       ...            ...    ...
# 229                                      NaN            NaN    NaN
# 230                                      NaN            NaN    NaN
# 231                                      NaN            NaN    NaN
# 232                                      NaN            NaN    NaN
# 233                                      NaN            NaN    NaN
#
#      effective depth  GeometricPlanDimension       l       a      c  \
# 0              132.7                  2750.0  2200.0  1000.0  200.0
# ...

# %%
df.describe()
# Out:
#         CylindricalConcreteCompressiveStrength  YieldStrength           H  \
# count                               224.000000     224.000000  224.000000
# mean                                 47.486607     479.357143  143.151786
# std                                  22.786431      82.911332   71.140291
# min                                  14.600000     321.300000   45.500000
# 25%                                  29.850000     435.000000  115.000000
# 50%                                  36.200000     495.000000  150.000000
# 75%                                  68.925000     530.000000  150.000000
# max                                 119.000000     628.000000  550.000000
#
#        effective depth  GeometricPlanDimension            l            a  \
# count       224.000000              224.000000   224.000000   224.000000
# mean        111.931518             1551.982143  1299.691964   532.428571
# std          64.533596              719.978774   665.402989   333.455444
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 14 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0    CylindricalConcreteCompressiveStrength  224 non-null    float64
#  1   YieldStrength                            224 non-null    float64
#  2   H                                        224 non-null    float64
#  3   effective depth                          224 non-null    float64
#  4   GeometricPlanDimension                   224 non-null    float64
#  5   l                                        224 non-null    float64
#  6   a                                        224 non-null    float64
#  7   c                                        224 non-null    float64
#  8   Cmax_Cmin_Ratio                          224 non-null    float64
#  9   Rho                                      224 non-null    float64
# ...

# %%
df
# Out:
#       CylindricalConcreteCompressiveStrength  YieldStrength      H  \
# 0                                       33.2          437.0  155.0
# 1                                       35.6          437.0  155.0
# 2                                       26.0          437.0  155.0
# 3                                       26.0          437.0  155.0
# 4                                       26.0          437.0  155.0
# ..                                       ...            ...    ...
# 229                                      NaN            NaN    NaN
# 230                                      NaN            NaN    NaN
# 231                                      NaN            NaN    NaN
# 232                                      NaN            NaN    NaN
# 233                                      NaN            NaN    NaN
#
#      effective depth  GeometricPlanDimension       l       a      c  \
# 0              132.7                  2750.0  2200.0  1000.0  200.0
# ...

# %%
df.columns
# Out:
# Index([' CylindricalConcreteCompressiveStrength', 'YieldStrength', 'H',
#        'effective depth', 'GeometricPlanDimension', 'l', 'a', 'c',
#        'Cmax_Cmin_Ratio', 'Rho', 'Rho_star', 'Rho_dash', 'P_test', 'Psst'],
#       dtype='object')

# %%
df = df.iloc[:-3,:]
df
# Out:
#       CylindricalConcreteCompressiveStrength  YieldStrength      H  \
# 0                                       33.2          437.0  155.0
# 1                                       35.6          437.0  155.0
# 2                                       26.0          437.0  155.0
# 3                                       26.0          437.0  155.0
# 4                                       26.0          437.0  155.0
# ..                                       ...            ...    ...
# 226                                      NaN            NaN    NaN
# 227                                      NaN            NaN    NaN
# 228                                      NaN            NaN    NaN
# 229                                      NaN            NaN    NaN
# 230                                      NaN            NaN    NaN
#
#      effective depth  GeometricPlanDimension       l       a      c  \
# 0              132.7                  2750.0  2200.0  1000.0  200.0
# ...

# %%
df = df.iloc[:223,:]
df
# Out:
#       CylindricalConcreteCompressiveStrength  YieldStrength      H  \
# 0                                       33.2          437.0  155.0
# 1                                       35.6          437.0  155.0
# 2                                       26.0          437.0  155.0
# 3                                       26.0          437.0  155.0
# 4                                       26.0          437.0  155.0
# ..                                       ...            ...    ...
# 218                                     30.4          414.0  150.0
# 219                                     23.9          416.0  150.0
# 220                                     30.1          416.0  150.0
# 221                                     19.8          352.0  150.0
# 222                                     16.0          352.0  150.0
#
#      effective depth  GeometricPlanDimension       l       a      c  \
# 0              132.7                  2750.0  2200.0  1000.0  200.0
# ...

# %%
data = df[[' CylindricalConcreteCompressiveStrength', 'YieldStrength', 'H','effective depth', 'GeometricPlanDimension', 'l', 'a', 'c','Cmax_Cmin_Ratio', 'Rho', 'P_test', 'Psst']]

# %%
data
# Out:
#       CylindricalConcreteCompressiveStrength  YieldStrength      H  \
# 0                                       33.2          437.0  155.0
# 1                                       35.6          437.0  155.0
# 2                                       26.0          437.0  155.0
# 3                                       26.0          437.0  155.0
# 4                                       26.0          437.0  155.0
# ..                                       ...            ...    ...
# 218                                     30.4          414.0  150.0
# 219                                     23.9          416.0  150.0
# 220                                     30.1          416.0  150.0
# 221                                     19.8          352.0  150.0
# 222                                     16.0          352.0  150.0
#
#      effective depth  GeometricPlanDimension       l       a      c  \
# 0              132.7                  2750.0  2200.0  1000.0  200.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 12 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0    CylindricalConcreteCompressiveStrength  223 non-null    float64
#  1   YieldStrength                            223 non-null    float64
#  2   H                                        223 non-null    float64
#  3   effective depth                          223 non-null    float64
#  4   GeometricPlanDimension                   223 non-null    float64
#  5   l                                        223 non-null    float64
#  6   a                                        223 non-null    float64
#  7   c                                        223 non-null    float64
#  8   Cmax_Cmin_Ratio                          223 non-null    float64
#  9   Rho                                      223 non-null    float64
# ...

# %%
sns.heatmap(data.corr(),cmap = "YlGnBu",annot = True)
# Out:
# <Axes: >

# %%
data2 = df[[' CylindricalConcreteCompressiveStrength', 'YieldStrength', 'H',
       'effective depth', 'GeometricPlanDimension', 'l', 'a', 'c',
       'Cmax_Cmin_Ratio', 'Rho', 'Rho_dash', 'P_test', 'Psst']]
data2
# Out:
#       CylindricalConcreteCompressiveStrength  YieldStrength      H  \
# 0                                       33.2          437.0  155.0
# 1                                       35.6          437.0  155.0
# 2                                       26.0          437.0  155.0
# 3                                       26.0          437.0  155.0
# 4                                       26.0          437.0  155.0
# ..                                       ...            ...    ...
# 218                                     30.4          414.0  150.0
# 219                                     23.9          416.0  150.0
# 220                                     30.1          416.0  150.0
# 221                                     19.8          352.0  150.0
# 222                                     16.0          352.0  150.0
#
#      effective depth  GeometricPlanDimension       l       a      c  \
# 0              132.7                  2750.0  2200.0  1000.0  200.0
# ...

# %%
data2['Rho_dash'] = data2['Rho_dash'].replace('-',pd.NA)
data2
# Out:
# <ipython-input-15-8507d6daf7d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['Rho_dash'] = data2['Rho_dash'].replace('-',pd.NA)
#       CylindricalConcreteCompressiveStrength  YieldStrength      H  \
# 0                                       33.2          437.0  155.0
# 1                                       35.6          437.0  155.0
# 2                                       26.0          437.0  155.0
# 3                                       26.0          437.0  155.0
# 4                                       26.0          437.0  155.0
# ..                                       ...            ...    ...
# 218                                     30.4          414.0  150.0
# ...

# %%
# prompt: in the dataframe data2 take only those rows in which the column 'Rho_dash' is not null

data2 = data2[pd.notnull(data2['Rho_dash'])]
data2
# Out:
#       CylindricalConcreteCompressiveStrength  YieldStrength      H  \
# 0                                       33.2          437.0  155.0
# 1                                       35.6          437.0  155.0
# 2                                       26.0          437.0  155.0
# 3                                       26.0          437.0  155.0
# 4                                       26.0          437.0  155.0
# ..                                       ...            ...    ...
# 196                                     38.9          462.0  125.0
# 197                                     38.9          462.0  125.0
# 203                                     86.7          550.0  240.0
# 205                                     80.3          550.0  240.0
# 206                                     98.0          550.0  240.0
#
#      effective depth  GeometricPlanDimension       l       a      c  \
# 0              132.7                  2750.0  2200.0  1000.0  200.0
# ...

# %%
sns.heatmap(data2.corr(), cmap = 'YlGnBu',annot = True)
# Out:
# <Axes: >
